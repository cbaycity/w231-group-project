# %%
import pandas as pd
import re
import numpy as np

fire_dep = pd.read_csv('Seattle_Real_Time_Fire_911_Calls.csv')
contractors = pd.read_csv('L_I_Contractor_License_Data_-_General.csv')

# %%
fire_dep.head()
# Out:
#                  Address          Type                Datetime   Latitude  \
# 0             904 7th Av      Car Fire  05/22/2019 12:55:00 PM  47.606900
# 1         9610 53rd Av S  Aid Response  05/22/2019 12:55:00 PM  47.515984
# 2            106 Pike St  Aid Response  05/22/2019 12:57:00 PM  47.608849
# 3            1902 2nd Av  Aid Response  07/01/2019 07:45:00 AM  47.610972
# 4  4737 Roosevelt Way Ne      Unk Odor  07/01/2019 07:45:00 AM  47.663338
#
#     Longitude                Report Location Incident Number
# 0 -122.329051    POINT (-122.329051 47.6069)      F190051945
# 1 -122.266529  POINT (-122.266529 47.515984)      F190051946
# 2 -122.339945  POINT (-122.339945 47.608849)      F190051950
# 3 -122.340465  POINT (-122.340465 47.610972)      F190068848
# 4 -122.317421  POINT (-122.317421 47.663338)      F190068849

# %%
contractors.head()
# Out:
#                    BusinessName ContractorLicenseNumber  \
# 0              VIKING POOLS INC            VIKINPI066JF
# 1             OSBORNE LANDSCAPE            OSBORL*822QO
# 2                 EARTHHEAT INC            EARTHI*792O7
# 3  TUMWATER DRILLING & PUMP INC            TUMWADP780US
# 4       HOME ENERGY EXPERTS LLC            HOMEEEE831MK
#
#   ContractorLicenseTypeCode ContractorLicenseTypeCodeDesc  \
# 0                        CC       CONSTRUCTION CONTRACTOR
# 1                        CC       CONSTRUCTION CONTRACTOR
# 2                        PC           PLUMBING CONTRACTOR
# 3                        EC         ELECTRICAL CONTRACTOR
# 4                        CC       CONSTRUCTION CONTRACTOR
#
#                Address1 Address2           City State    Zip   PhoneNumber  \
# 0  11506 Meridian Ave N      NaN        SEATTLE    WA  98133  2.066691e+09
# 1     812 N GRANITE AVE      NaN  GRANITE FALLS    WA  98252  4.255958e+09
# 2            PO BOX 819      NaN         DUVALL    WA  98019  4.257885e+09
# 3           P O BOX 249      NaN         DRYDEN    WA  98821  5.095485e+09
# 4   1110 NORTH 650 WEST      NaN    CENTERVILLE    UT  84014  8.553626e+09
#
#    ...       BusinessTypeCodeDesc SpecialtyCode1 SpecialtyCode1Desc  \
# 0  ...                Corporation             01            GENERAL
# 1  ...                 Individual             BW        LANDSCAPING
# 2  ...                Corporation             01      JOURNEY LEVEL
# 3  ...                Corporation             3A      Domestic Pump
# 4  ...  Limited Liability Company             01            GENERAL
#
#   SpecialtyCode2 SpecialtyCode2Desc        UBI    PrimaryPrincipalName  \
# 0            NaN                NaN  601530138   JOHNSON, MIKAL WALTER
# 1            NaN                NaN  604008069    OSBORNE, ANGELA LYNN
# 2            NaN                NaN  602593890    MALONEY, GERARD JUDE
# 3             91                NaN  600164144          Webb, Dennis O
# 4            NaN                NaN  603500846  CHRISTENSEN, DON SCOTT
#
#   StatusCode  ContractorLicenseStatus ContractorLicenseSuspendDate
# 0          S                SUSPENDED                   10/06/2021
# 1          A                   ACTIVE                          NaN
# 2          A                   ACTIVE                          NaN
# 3          A                   ACTIVE                          NaN
# 4          A                   ACTIVE                          NaN
#
# [5 rows x 23 columns]

# %%
# Need to data clean with the steps below:
# lower
# remove punctuation

def apply_regex(address):
    '''Uses regular expressions to format the address data fora join.'''
    
    address = str(address)
    
    new_str = address.lower()
    end_str = re.sub(r'[^\w\s]', '', new_str)
    
    return end_str

print(apply_regex(contractors['Address1'][0]))

contractors['join_address'] = contractors['Address1'].apply(apply_regex)
fire_dep['join_address'] = fire_dep['Address'].apply(apply_regex)
# Out:
# 11506 meridian ave n

# %%
# Need to get only the most recent contractor for each address in the contractors dataset. 
contractors['recency'] = contractors.sort_values(['LicenseEffectiveDate'])\
    .groupby(['join_address'])\
    .cumcount() + 1

# a recency of 1 is the newest record. 

contractors[contractors['join_address'] == '0607 sw idaho st'][['LicenseEffectiveDate', 'recency']]

contractors = contractors[contractors['recency'] == 1]

# %%
# Need to think about other data cleaning steps to improve the re-identification.

# %%
# Manages the join. 

joined_data = pd.merge(fire_dep, contractors, on = "join_address", how = 'left')
joined_data.sort_values(['recency']).head()
# Out:
#                    Address                       Type                Datetime  \
# 63          1238 S KING ST               Aid Response  03/23/2022 11:23:00 AM
# 1374429   400 S Jackson St           Fire in Building  05/04/2021 07:36:00 AM
# 1374276    600 E Howell St             Medic Response  12/30/2021 07:22:00 PM
# 1374196  1818 E Madison St        Low Acuity Response  03/31/2022 11:47:00 PM
# 1374149   7713 10th Ave Nw  Automatic Fire Alarm Resd  01/08/2021 08:22:00 PM
#
#           Latitude   Longitude                Report Location Incident Number  \
# 63       47.598337 -122.316495  POINT (-122.316495 47.598337)      F220033866
# 1374429  47.599197 -122.328968  POINT (-122.328968 47.599197)      F210043866
# 1374276  47.617746 -122.324505  POINT (-122.324505 47.617746)      F210145497
# 1374196  47.616245 -122.308579  POINT (-122.308579 47.616245)      F220037339
# 1374149  47.685163 -122.369339  POINT (-122.369339 47.685163)      F210002461
#
#               join_address                   BusinessName  \
# 63          1238 s king st                   Action Jacob
# 1374429   400 s jackson st           SDV CONSTRUCTION LLC
# 1374276    600 e howell st  HENDERSON & ABRAHA PROPERTIES
# 1374196  1818 e madison st                 S J P SERVICES
# 1374149   7713 10th ave nw                      M G H INC
#
#         ContractorLicenseNumber  ... SpecialtyCode1 SpecialtyCode1Desc  \
# 63                 ACTIOJ*827N7  ...             01            GENERAL
# 1374429            SDVCOCL797D3  ...             01            GENERAL
# 1374276            HENDEAP868DR  ...             01            GENERAL
# 1374196            SJPSES*925DG  ...             HM           HANDYMAN
# 1374149            MGHIN**031J2  ...             01            GENERAL
#
#         SpecialtyCode2 SpecialtyCode2Desc          UBI   PrimaryPrincipalName  \
# 63                 NaN                NaN  604222186.0         Dwyer, Jacob M
# 1374429            NaN                NaN  604711918.0    VLAHOVICH, STEVEN D
# 1374276            NaN                NaN  603369759.0       HENDERSON, RALPH
# 1374196            NaN                NaN  602801306.0      PAULIS, STEPHEN J
# 1374149            NaN                NaN  601758571.0  HAMSTRA, MICHAEL GENE
#
#         StatusCode  ContractorLicenseStatus ContractorLicenseSuspendDate  \
# 63               R              RE-LICENSED                   03/12/2020
# 1374429          S                SUSPENDED                   02/17/2022
# 1374276          E                  EXPIRED                   03/10/2021
# 1374196          A                   ACTIVE                          NaN
# 1374149          A                   ACTIVE                          NaN
#
#         recency
# 63          1.0
# 1374429     1.0
# 1374276     1.0
# 1374196     1.0
# 1374149     1.0
#
# [5 rows x 32 columns]

# %%
# Calculates what percentage of fire department emergencies are linked to contractors. 

total_incidents = len(joined_data)
joined_incidents = len(joined_data[np.isnan(joined_data['recency']) == False])

# %%
print('Percent of the dataset identified: ', 100 * joined_incidents / total_incidents)
# Out:
# Percent of the dataset identified:  1.138138756789852

# %%
# need to think about joining on dates so that you only get incidents 
# that are after the contractor moved into the unit.
